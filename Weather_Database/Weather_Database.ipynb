# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-90, 90, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 790

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url)
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
          
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})  
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | caravelas
# Processing Record 2 of Set 1 | sainte-maxime
# Processing Record 3 of Set 1 | chuy
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | kamthi
# Processing Record 6 of Set 1 | north myrtle beach
# Processing Record 7 of Set 1 | bubaque
# Processing Record 8 of Set 1 | handwara
# City not found. Skipping...
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | cidreira
# Processing Record 11 of Set 1 | ostrovnoy
# Processing Record 12 of Set 1 | ribeira grande
# Processing Record 13 of Set 1 | necochea
# Processing Record 14 of Set 1 | nevsehir
# Processing Record 15 of Set 1 | saurimo
# Processing Record 16 of Set 1 | kumluca
# Processing Record 17 of Set 1 | grand gaube
# Processing Record 18 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | sinnamary
# Processing Record 21 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | richards bay
# Processing Record 24 of Set 1 | raga
# Processing Record 25 of Set 1 | mondlo
# Processing Record 26 of Set 1 | lagoa
# Processing Record 27 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | sao filipe
# Processing Record 30 of Set 1 | sergeyevka
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | laguna
# Processing Record 33 of Set 1 | kouroussa
# Processing Record 34 of Set 1 | bereda
# Processing Record 35 of Set 1 | nanortalik
# Processing Record 36 of Set 1 | abay
# Processing Record 37 of Set 1 | coihaique
# Processing Record 38 of Set 1 | salvador
# Processing Record 39 of Set 1 | opoczno
# Processing Record 40 of Set 1 | port elizabeth
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | vila velha
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | hattiesburg
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | tashara
# Processing Record 47 of Set 1 | san cristobal
# Processing Record 48 of Set 1 | berlevag
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | damaturu
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | mayumba
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | gilgil
# City not found. Skipping...
# Processing Record 6 of Set 2 | upernavik
# Processing Record 7 of Set 2 | bondo
# Processing Record 8 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | klaksvik
# Processing Record 11 of Set 2 | anloga
# Processing Record 12 of Set 2 | axim
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | mount pleasant
# Processing Record 17 of Set 2 | touros
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | talara
# Processing Record 20 of Set 2 | atar
# Processing Record 21 of Set 2 | burica
# City not found. Skipping...
# Processing Record 22 of Set 2 | carballo
# Processing Record 23 of Set 2 | luderitz
# Processing Record 24 of Set 2 | maldonado
# Processing Record 25 of Set 2 | vardo
# Processing Record 26 of Set 2 | birao
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | codrington
# Processing Record 29 of Set 2 | bedele
# Processing Record 30 of Set 2 | fatezh
# Processing Record 31 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 32 of Set 2 | japura
# Processing Record 33 of Set 2 | coquimbo
# Processing Record 34 of Set 2 | pangody
# Processing Record 35 of Set 2 | amapa
# Processing Record 36 of Set 2 | keetmanshoop
# Processing Record 37 of Set 2 | saldanha
# Processing Record 38 of Set 2 | iranduba
# Processing Record 39 of Set 2 | amalapuram
# Processing Record 40 of Set 2 | bambous virieux
# Processing Record 41 of Set 2 | belmonte
# Processing Record 42 of Set 2 | havre-saint-pierre
# Processing Record 43 of Set 2 | moundsville
# Processing Record 44 of Set 2 | beysehir
# Processing Record 45 of Set 2 | hithadhoo
# Processing Record 46 of Set 2 | souillac
# Processing Record 47 of Set 2 | cayeli
# Processing Record 48 of Set 2 | linhares
# Processing Record 49 of Set 2 | semey
# Processing Record 50 of Set 2 | bandarbeyla
# Processing Record 1 of Set 3 | punta umbria
# Processing Record 2 of Set 3 | lokosovo
# Processing Record 3 of Set 3 | canoinhas
# Processing Record 4 of Set 3 | logrono
# Processing Record 5 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 3 | mar del plata
# Processing Record 7 of Set 3 | victoria
# Processing Record 8 of Set 3 | rendsburg
# Processing Record 9 of Set 3 | hermanus
# Processing Record 10 of Set 3 | pucallpa
# Processing Record 11 of Set 3 | tocopilla
# Processing Record 12 of Set 3 | cayenne
# Processing Record 13 of Set 3 | mahon
# Processing Record 14 of Set 3 | saint george
# Processing Record 15 of Set 3 | mahebourg
# Processing Record 16 of Set 3 | porto belo
# Processing Record 17 of Set 3 | ardistan
# City not found. Skipping...
# Processing Record 18 of Set 3 | toamasina
# Processing Record 19 of Set 3 | grindavik
# Processing Record 20 of Set 3 | limeil-brevannes
# Processing Record 21 of Set 3 | veraval
# Processing Record 22 of Set 3 | chimbote
# Processing Record 23 of Set 3 | columbia
# Processing Record 24 of Set 3 | karasburg
# Processing Record 25 of Set 3 | ogbomosho
# Processing Record 26 of Set 3 | venice
# Processing Record 27 of Set 3 | cape canaveral
# Processing Record 28 of Set 3 | matagami
# Processing Record 29 of Set 3 | kogon
# Processing Record 30 of Set 3 | baghramyan
# Processing Record 31 of Set 3 | leh
# Processing Record 32 of Set 3 | zaragoza
# Processing Record 33 of Set 3 | muros
# Processing Record 34 of Set 3 | naryan-mar
# Processing Record 35 of Set 3 | dingle
# Processing Record 36 of Set 3 | ashqelon
# Processing Record 37 of Set 3 | killybegs
# Processing Record 38 of Set 3 | kubuta
# Processing Record 39 of Set 3 | erzincan
# Processing Record 40 of Set 3 | hambantota
# Processing Record 41 of Set 3 | normandin
# Processing Record 42 of Set 3 | buraydah
# Processing Record 43 of Set 3 | dudinka
# Processing Record 44 of Set 3 | gornyy
# Processing Record 45 of Set 3 | banda aceh
# Processing Record 46 of Set 3 | wattegama
# Processing Record 47 of Set 3 | sibi
# Processing Record 48 of Set 3 | sidi ali
# Processing Record 49 of Set 3 | palmeiras de goias
# Processing Record 50 of Set 3 | sur
# Processing Record 1 of Set 4 | wlodawa
# Processing Record 2 of Set 4 | arrecife
# Processing Record 3 of Set 4 | eydhafushi
# Processing Record 4 of Set 4 | clyde river
# Processing Record 5 of Set 4 | tiznit
# Processing Record 6 of Set 4 | inirida
# Processing Record 7 of Set 4 | kashi
# Processing Record 8 of Set 4 | panaba
# Processing Record 9 of Set 4 | faya
# Processing Record 10 of Set 4 | ponnani
# Processing Record 11 of Set 4 | banes
# Processing Record 12 of Set 4 | the valley
# Processing Record 13 of Set 4 | najran
# Processing Record 14 of Set 4 | humaita
# Processing Record 15 of Set 4 | gauripur
# Processing Record 16 of Set 4 | port shepstone
# Processing Record 17 of Set 4 | buzmeyin
# Processing Record 18 of Set 4 | peno
# Processing Record 19 of Set 4 | comodoro rivadavia
# Processing Record 20 of Set 4 | windhoek
# Processing Record 21 of Set 4 | placido de castro
# Processing Record 22 of Set 4 | nushki
# Processing Record 23 of Set 4 | abonnema
# Processing Record 24 of Set 4 | keflavik
# Processing Record 25 of Set 4 | carnarvon
# Processing Record 26 of Set 4 | korla
# Processing Record 27 of Set 4 | ohrid
# Processing Record 28 of Set 4 | new waterford
# Processing Record 29 of Set 4 | aosta
# Processing Record 30 of Set 4 | novoalekseyevskaya
# Processing Record 31 of Set 4 | dhidhdhoo
# Processing Record 32 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 4 | mogadishu
# Processing Record 34 of Set 4 | riyadh
# Processing Record 35 of Set 4 | turukhansk
# Processing Record 36 of Set 4 | geraldton
# Processing Record 37 of Set 4 | rudiskes
# Processing Record 38 of Set 4 | kavaratti
# Processing Record 39 of Set 4 | taltal
# Processing Record 40 of Set 4 | antofagasta
# Processing Record 41 of Set 4 | taoudenni
# Processing Record 42 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 4 | ponta do sol
# Processing Record 44 of Set 4 | camacupa
# Processing Record 45 of Set 4 | mana
# Processing Record 46 of Set 4 | mosquera
# Processing Record 47 of Set 4 | odzak
# Processing Record 48 of Set 4 | mercedes
# Processing Record 49 of Set 4 | pisco
# Processing Record 50 of Set 4 | hobyo
# Processing Record 1 of Set 5 | porto santo
# Processing Record 2 of Set 5 | lahij
# Processing Record 3 of Set 5 | tessalit
# Processing Record 4 of Set 5 | puerto colombia
# Processing Record 5 of Set 5 | soverato
# Processing Record 6 of Set 5 | uarini
# Processing Record 7 of Set 5 | ewo
# Processing Record 8 of Set 5 | kidal
# Processing Record 9 of Set 5 | pangnirtung
# Processing Record 10 of Set 5 | oranjestad
# Processing Record 11 of Set 5 | el balyana
# City not found. Skipping...
# Processing Record 12 of Set 5 | thinadhoo
# Processing Record 13 of Set 5 | estelle
# Processing Record 14 of Set 5 | palora
# Processing Record 15 of Set 5 | umm kaddadah
# Processing Record 16 of Set 5 | kautokeino
# Processing Record 17 of Set 5 | saint-augustin
# Processing Record 18 of Set 5 | port-gentil
# Processing Record 19 of Set 5 | mazsalaca
# Processing Record 20 of Set 5 | torbay
# Processing Record 21 of Set 5 | ashington
# Processing Record 22 of Set 5 | ciudad bolivar
# Processing Record 23 of Set 5 | coruripe
# Processing Record 24 of Set 5 | kambove
# Processing Record 25 of Set 5 | marand
# Processing Record 26 of Set 5 | urucui
# Processing Record 27 of Set 5 | mayahi
# Processing Record 28 of Set 5 | hofn
# Processing Record 29 of Set 5 | ilulissat
# Processing Record 30 of Set 5 | opuwo
# Processing Record 31 of Set 5 | autazes
# Processing Record 32 of Set 5 | saint-pierre
# Processing Record 33 of Set 5 | iquique
# Processing Record 34 of Set 5 | srivardhan
# Processing Record 35 of Set 5 | harper
# Processing Record 36 of Set 5 | jawar
# Processing Record 37 of Set 5 | la palma
# Processing Record 38 of Set 5 | ozimek
# Processing Record 39 of Set 5 | langres
# Processing Record 40 of Set 5 | montlucon
# Processing Record 41 of Set 5 | port hawkesbury
# Processing Record 42 of Set 5 | jaru
# Processing Record 43 of Set 5 | bathsheba
# Processing Record 44 of Set 5 | biltine
# Processing Record 45 of Set 5 | takoradi
# Processing Record 46 of Set 5 | durban
# Processing Record 47 of Set 5 | porbandar
# Processing Record 48 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 5 | padang
# Processing Record 50 of Set 5 | saint anthony
# Processing Record 1 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 6 | nuuk
# Processing Record 3 of Set 6 | kharitonovo
# Processing Record 4 of Set 6 | gagino
# Processing Record 5 of Set 6 | montes claros
# Processing Record 6 of Set 6 | yar-sale
# Processing Record 7 of Set 6 | yialos
# City not found. Skipping...
# Processing Record 8 of Set 6 | gusau
# Processing Record 9 of Set 6 | san juan
# Processing Record 10 of Set 6 | marsh harbour
# Processing Record 11 of Set 6 | meaux
# Processing Record 12 of Set 6 | quelimane
# Processing Record 13 of Set 6 | paamiut
# Processing Record 14 of Set 6 | ugoofaaru
# Processing Record 15 of Set 6 | porto velho
# Processing Record 16 of Set 6 | shahdadkot
# Processing Record 17 of Set 6 | sisimiut
# Processing Record 18 of Set 6 | miraflores
# Processing Record 19 of Set 6 | lodwar
# Processing Record 20 of Set 6 | struga
# Processing Record 21 of Set 6 | mecca
# Processing Record 22 of Set 6 | jirkov
# Processing Record 23 of Set 6 | sao miguel do araguaia
# Processing Record 24 of Set 6 | karasjok
# Processing Record 25 of Set 6 | usinsk
# Processing Record 26 of Set 6 | puerto leguizamo
# Processing Record 27 of Set 6 | mitsamiouli
# Processing Record 28 of Set 6 | krasnoselkup
# Processing Record 29 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 6 | yashkul
# Processing Record 31 of Set 6 | wilmington
# Processing Record 32 of Set 6 | ape
# Processing Record 33 of Set 6 | mul
# Processing Record 34 of Set 6 | pitimbu
# Processing Record 35 of Set 6 | peniche
# Processing Record 36 of Set 6 | uch
# Processing Record 37 of Set 6 | mizdah
# Processing Record 38 of Set 6 | abu kamal
# Processing Record 39 of Set 6 | eyl
# Processing Record 40 of Set 6 | chute-aux-outardes
# Processing Record 41 of Set 6 | namibe
# Processing Record 42 of Set 6 | monkey bay
# Processing Record 43 of Set 6 | abu samrah
# Processing Record 44 of Set 6 | madimba
# Processing Record 45 of Set 6 | iguape
# Processing Record 46 of Set 6 | coari
# Processing Record 47 of Set 6 | diffa
# Processing Record 48 of Set 6 | olafsvik
# Processing Record 49 of Set 6 | sao joao de pirabas
# Processing Record 50 of Set 6 | nueva loja
# Processing Record 1 of Set 7 | darnah
# Processing Record 2 of Set 7 | emba
# Processing Record 3 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 4 of Set 7 | dolgoderevenskoye
# Processing Record 5 of Set 7 | sorland
# Processing Record 6 of Set 7 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 7 of Set 7 | mezen
# Processing Record 8 of Set 7 | nienburg
# Processing Record 9 of Set 7 | los llanos de aridane
# Processing Record 10 of Set 7 | ceccano
# Processing Record 11 of Set 7 | tazovskiy
# Processing Record 12 of Set 7 | tres passos
# Processing Record 13 of Set 7 | jabinyanah
# Processing Record 14 of Set 7 | sao raimundo das mangabeiras
# Processing Record 15 of Set 7 | wukari
# Processing Record 16 of Set 7 | afyonkarahisar
# Processing Record 17 of Set 7 | shamary
# Processing Record 18 of Set 7 | kensington
# Processing Record 19 of Set 7 | knysna
# Processing Record 20 of Set 7 | sertanopolis
# Processing Record 21 of Set 7 | evreux
# Processing Record 22 of Set 7 | lalibela
# Processing Record 23 of Set 7 | alpena
# Processing Record 24 of Set 7 | soligalich
# Processing Record 25 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 7 | magole
# Processing Record 27 of Set 7 | la serena
# Processing Record 28 of Set 7 | santa isabel do rio negro
# Processing Record 29 of Set 7 | krasnyy yar
# Processing Record 30 of Set 7 | seredka
# Processing Record 31 of Set 7 | bilma
# Processing Record 32 of Set 7 | tonekabon
# Processing Record 33 of Set 7 | rawson
# Processing Record 34 of Set 7 | koungou
# Processing Record 35 of Set 7 | marzuq
# Processing Record 36 of Set 7 | kruisfontein
# Processing Record 37 of Set 7 | vila do maio
# Processing Record 38 of Set 7 | bomet
# Processing Record 39 of Set 7 | garmsar
# Processing Record 40 of Set 7 | sistranda
# Processing Record 41 of Set 7 | bulawayo
# Processing Record 42 of Set 7 | banikoara
# Processing Record 43 of Set 7 | brae
# Processing Record 44 of Set 7 | port-cartier
# Processing Record 45 of Set 7 | costinesti
# Processing Record 46 of Set 7 | sakakah
# Processing Record 47 of Set 7 | iqaluit
# Processing Record 48 of Set 7 | limon
# Processing Record 49 of Set 7 | gweta
# Processing Record 50 of Set 7 | falanna
# Processing Record 1 of Set 8 | marovoay
# Processing Record 2 of Set 8 | gunjur
# Processing Record 3 of Set 8 | cordoba
# Processing Record 4 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 5 of Set 8 | ouadda
# Processing Record 6 of Set 8 | ornes
# Processing Record 7 of Set 8 | phalaborwa
# Processing Record 8 of Set 8 | oranjemund
# Processing Record 9 of Set 8 | rundu
# Processing Record 10 of Set 8 | dwarka
# Processing Record 11 of Set 8 | san ignacio de sabaneta
# City not found. Skipping...
# Processing Record 12 of Set 8 | yarega
# Processing Record 13 of Set 8 | jalu
# Processing Record 14 of Set 8 | boden
# Processing Record 15 of Set 8 | pryluky
# Processing Record 16 of Set 8 | sumbe
# Processing Record 17 of Set 8 | villa maria
# Processing Record 18 of Set 8 | itaituba
# Processing Record 19 of Set 8 | tolstoy-yurt
# Processing Record 20 of Set 8 | jabalpur
# Processing Record 21 of Set 8 | zelenets
# Processing Record 22 of Set 8 | unjha
# Processing Record 23 of Set 8 | umaria
# Processing Record 24 of Set 8 | gloversville
# Processing Record 25 of Set 8 | uzhur
# Processing Record 26 of Set 8 | sao jose da coroa grande
# Processing Record 27 of Set 8 | mut
# Processing Record 28 of Set 8 | san rafael
# Processing Record 29 of Set 8 | purna
# Processing Record 30 of Set 8 | sechura
# Processing Record 31 of Set 8 | encruzilhada do sul
# Processing Record 32 of Set 8 | jega
# Processing Record 33 of Set 8 | bogotol
# Processing Record 34 of Set 8 | porteirinha
# Processing Record 35 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 36 of Set 8 | tonantins
# Processing Record 37 of Set 8 | teguise
# Processing Record 38 of Set 8 | alagoa grande
# Processing Record 39 of Set 8 | virginia beach
# Processing Record 40 of Set 8 | ilorin
# Processing Record 41 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 42 of Set 8 | saint john
# Processing Record 43 of Set 8 | valparaiso
# Processing Record 44 of Set 8 | alta floresta
# Processing Record 45 of Set 8 | tallahassee
# Processing Record 46 of Set 8 | kologriv
# Processing Record 47 of Set 8 | vila franca do campo
# Processing Record 48 of Set 8 | nampula
# Processing Record 49 of Set 8 | rosa zarate
# Processing Record 50 of Set 8 | nuevitas
# Processing Record 1 of Set 9 | basyanovskiy
# City not found. Skipping...
# Processing Record 2 of Set 9 | sioux lookout
# Processing Record 3 of Set 9 | igarka
# Processing Record 4 of Set 9 | tyukhtet
# Processing Record 5 of Set 9 | raudeberg
# Processing Record 6 of Set 9 | aktau
# Processing Record 7 of Set 9 | henties bay
# Processing Record 8 of Set 9 | alberdi
# Processing Record 9 of Set 9 | yarada
# Processing Record 10 of Set 9 | poltava
# Processing Record 11 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 9 | tweed
# Processing Record 13 of Set 9 | husavik
# Processing Record 14 of Set 9 | sosnovo
# Processing Record 15 of Set 9 | kaniama
# Processing Record 16 of Set 9 | oriximina
# Processing Record 17 of Set 9 | mahalapye
# Processing Record 18 of Set 9 | antalaha
# Processing Record 19 of Set 9 | nalut
# Processing Record 20 of Set 9 | uige
# Processing Record 21 of Set 9 | verkhnyaya inta
# Processing Record 22 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 24 of Set 9 | kalmunai
# Processing Record 25 of Set 9 | sinnar
# Processing Record 26 of Set 9 | tank
# Processing Record 27 of Set 9 | kattivakkam
# Processing Record 28 of Set 9 | fulacunda
# City not found. Skipping...
# Processing Record 29 of Set 9 | pailon
# Processing Record 30 of Set 9 | cockburn town
# Processing Record 31 of Set 9 | neyshabur
# Processing Record 32 of Set 9 | prnjavor
# Processing Record 33 of Set 9 | imeni zhelyabova
# Processing Record 34 of Set 9 | sinop
# Processing Record 35 of Set 9 | anzio
# Processing Record 36 of Set 9 | naples
# Processing Record 37 of Set 9 | marabba
# Processing Record 38 of Set 9 | albox
# Processing Record 39 of Set 9 | rincon
# Processing Record 40 of Set 9 | mao
# Processing Record 41 of Set 9 | pontes e lacerda
# Processing Record 42 of Set 9 | sao jose do belmonte
# Processing Record 43 of Set 9 | hamilton
# Processing Record 44 of Set 9 | trinidad
# Processing Record 45 of Set 9 | santa cruz
# Processing Record 46 of Set 9 | botwood
# Processing Record 47 of Set 9 | sovetskiy
# Processing Record 48 of Set 9 | luba
# Processing Record 49 of Set 9 | ous
# Processing Record 50 of Set 9 | calbuco
# Processing Record 1 of Set 10 | peterborough
# Processing Record 2 of Set 10 | concepcion
# Processing Record 3 of Set 10 | narsaq
# Processing Record 4 of Set 10 | vorotynsk
# Processing Record 5 of Set 10 | esik
# Processing Record 6 of Set 10 | chapais
# Processing Record 7 of Set 10 | saumur
# Processing Record 8 of Set 10 | qaqortoq
# Processing Record 9 of Set 10 | channel-port aux basques
# Processing Record 10 of Set 10 | ilmenau
# Processing Record 11 of Set 10 | azare
# Processing Record 12 of Set 10 | westport
# Processing Record 13 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 10 | la romana
# Processing Record 15 of Set 10 | bangassou
# Processing Record 16 of Set 10 | turbat
# Processing Record 17 of Set 10 | rocha
# Processing Record 18 of Set 10 | monrovia
# Processing Record 19 of Set 10 | salalah
# Processing Record 20 of Set 10 | itaberai
# Processing Record 21 of Set 10 | maniitsoq
# Processing Record 22 of Set 10 | domoni
# Processing Record 23 of Set 10 | barao de melgaco
# Processing Record 24 of Set 10 | mitu
# Processing Record 25 of Set 10 | chabahar
# Processing Record 26 of Set 10 | riviere-au-renard
# Processing Record 27 of Set 10 | visnes
# Processing Record 28 of Set 10 | omboue
# Processing Record 29 of Set 10 | chicama
# Processing Record 30 of Set 10 | atbasar
# Processing Record 31 of Set 10 | isabela
# Processing Record 32 of Set 10 | kutum
# Processing Record 33 of Set 10 | agadir
# Processing Record 34 of Set 10 | joshimath
# Processing Record 35 of Set 10 | gorodishche
# Processing Record 36 of Set 10 | shu
# Processing Record 37 of Set 10 | bardiyah
# Processing Record 38 of Set 10 | nizhniy baskunchak
# Processing Record 39 of Set 10 | punta cardon
# Processing Record 40 of Set 10 | arenal
# Processing Record 41 of Set 10 | camocim
# Processing Record 42 of Set 10 | marawi
# Processing Record 43 of Set 10 | el alto
# Processing Record 44 of Set 10 | akdepe
# Processing Record 45 of Set 10 | nepomuceno
# Processing Record 46 of Set 10 | kisangani
# Processing Record 47 of Set 10 | ferme-neuve
# Processing Record 48 of Set 10 | albany
# Processing Record 49 of Set 10 | santa lucia
# Processing Record 50 of Set 10 | mitilini
# City not found. Skipping...
# Processing Record 1 of Set 11 | kondinskoye
# Processing Record 2 of Set 11 | abu dhabi
# Processing Record 3 of Set 11 | yining
# Processing Record 4 of Set 11 | pocoes
# Processing Record 5 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 7 of Set 11 | wadi maliz
# Processing Record 8 of Set 11 | miranda
# Processing Record 9 of Set 11 | tsaratanana
# Processing Record 10 of Set 11 | skjervoy
# Processing Record 11 of Set 11 | mehriz
# Processing Record 12 of Set 11 | dakar
# Processing Record 13 of Set 11 | medzev
# Processing Record 14 of Set 11 | leshukonskoye
# Processing Record 15 of Set 11 | kamenka
# Processing Record 16 of Set 11 | kudahuvadhoo
# Processing Record 17 of Set 11 | hualmay
# Processing Record 18 of Set 11 | nicoya
# Processing Record 19 of Set 11 | gornopravdinsk
# Processing Record 20 of Set 11 | butembo
# Processing Record 21 of Set 11 | yaval
# Processing Record 22 of Set 11 | ponta delgada
# Processing Record 23 of Set 11 | adre
# Processing Record 24 of Set 11 | jacareacanga
# Processing Record 25 of Set 11 | belize
# Processing Record 26 of Set 11 | kazanskoye
# Processing Record 27 of Set 11 | marathon
# Processing Record 28 of Set 11 | oksfjord
# Processing Record 29 of Set 11 | agnibilekrou
# Processing Record 30 of Set 11 | cap malheureux
# Processing Record 31 of Set 11 | great yarmouth
# Processing Record 32 of Set 11 | odweyne
# Processing Record 33 of Set 11 | barberton
# Processing Record 34 of Set 11 | huarmey
# Processing Record 35 of Set 11 | san andres
# Processing Record 36 of Set 11 | inhambane
# Processing Record 37 of Set 11 | nassau
# Processing Record 38 of Set 11 | awbari
# Processing Record 39 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 11 | mugla
# Processing Record 41 of Set 11 | khuzdar
# Processing Record 42 of Set 11 | mantua
# Processing Record 43 of Set 11 | diu
# Processing Record 44 of Set 11 | morondava
# Processing Record 45 of Set 11 | bajil
# Processing Record 46 of Set 11 | mekhe
# Processing Record 47 of Set 11 | balkhash
# Processing Record 48 of Set 11 | rensvik
# Processing Record 49 of Set 11 | yenagoa
# Processing Record 50 of Set 11 | antanifotsy
# Processing Record 1 of Set 12 | romitan
# Processing Record 2 of Set 12 | banyo
# Processing Record 3 of Set 12 | kango
# Processing Record 4 of Set 12 | witu
# Processing Record 5 of Set 12 | iquitos
# Processing Record 6 of Set 12 | akhmim
# Processing Record 7 of Set 12 | olinda
# Processing Record 8 of Set 12 | potosi
# Processing Record 9 of Set 12 | lubango
# Processing Record 10 of Set 12 | les cayes
# Processing Record 11 of Set 12 | shibarghan
# City not found. Skipping...
# Processing Record 12 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 13 of Set 12 | paramonga
# Processing Record 14 of Set 12 | quatre cocos
# Processing Record 15 of Set 12 | benguela
# Processing Record 16 of Set 12 | sabla
# Processing Record 17 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 18 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 12 | luena
# Processing Record 20 of Set 12 | bageshwar
# Processing Record 21 of Set 12 | nizhneivkino
# Processing Record 22 of Set 12 | floresti
# Processing Record 23 of Set 12 | maceio
# Processing Record 24 of Set 12 | saint-francois
# Processing Record 25 of Set 12 | guasdualito
# Processing Record 26 of Set 12 | gardelegen
# Processing Record 27 of Set 12 | puri
# Processing Record 28 of Set 12 | beloha
# Processing Record 29 of Set 12 | sagauli
# Processing Record 30 of Set 12 | jagdalpur
# Processing Record 31 of Set 12 | canutama
# Processing Record 32 of Set 12 | mocuba
# Processing Record 33 of Set 12 | betare oya
# Processing Record 34 of Set 12 | baboua
# City not found. Skipping...
# Processing Record 35 of Set 12 | sukhumi
# Processing Record 36 of Set 12 | laurinburg
# Processing Record 37 of Set 12 | zwedru
# Processing Record 38 of Set 12 | bougouni
# Processing Record 39 of Set 12 | bengkulu
# Processing Record 40 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 41 of Set 12 | surt
# Processing Record 42 of Set 12 | margate
# Processing Record 43 of Set 12 | pitsunda
# Processing Record 44 of Set 12 | rawatsar
# Processing Record 45 of Set 12 | san jose
# Processing Record 46 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 47 of Set 12 | skole
# Processing Record 48 of Set 12 | palmito
# Processing Record 49 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 50 of Set 12 | morant bay
# Processing Record 1 of Set 13 | gat
# Processing Record 2 of Set 13 | floro
# Processing Record 3 of Set 13 | chandla
# Processing Record 4 of Set 13 | grodzisk wielkopolski
# Processing Record 5 of Set 13 | bull savanna
# Processing Record 6 of Set 13 | shelburne
# Processing Record 7 of Set 13 | vavuniya
# Processing Record 8 of Set 13 | aksu
# Processing Record 9 of Set 13 | alwar
# Processing Record 10 of Set 13 | meulaboh
# Processing Record 11 of Set 13 | cape coast
# Processing Record 12 of Set 13 | candido mendes
# Processing Record 13 of Set 13 | la asuncion
# Processing Record 14 of Set 13 | rovaniemi
# Processing Record 15 of Set 13 | warrington
# Processing Record 16 of Set 13 | iranshahr
# Processing Record 17 of Set 13 | camopi
# Processing Record 18 of Set 13 | shubarshi
# Processing Record 19 of Set 13 | solvychegodsk
# Processing Record 20 of Set 13 | agadez
# Processing Record 21 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 22 of Set 13 | thunder bay
# Processing Record 23 of Set 13 | cuenca
# Processing Record 24 of Set 13 | le vauclin
# Processing Record 25 of Set 13 | grand-bourg
# Processing Record 26 of Set 13 | telimele
# Processing Record 27 of Set 13 | morros
# Processing Record 28 of Set 13 | aksarka
# Processing Record 29 of Set 13 | buxton
# Processing Record 30 of Set 13 | palmital
# Processing Record 31 of Set 13 | vreed en hoop
# City not found. Skipping...
# Processing Record 32 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 33 of Set 13 | pilao arcado
# City not found. Skipping...
# Processing Record 34 of Set 13 | la maddalena
# Processing Record 35 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 36 of Set 13 | tutoia
# Processing Record 37 of Set 13 | kadhan
# Processing Record 38 of Set 13 | krasnousolskiy
# City not found. Skipping...
# Processing Record 39 of Set 13 | blyth
# Processing Record 40 of Set 13 | manoel urbano
# Processing Record 41 of Set 13 | boysun
# Processing Record 42 of Set 13 | belokurikha
# Processing Record 43 of Set 13 | alcaniz
# Processing Record 44 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 45 of Set 13 | anar darreh
# City not found. Skipping...
# Processing Record 46 of Set 13 | matara
# Processing Record 47 of Set 13 | mormugao
# Processing Record 48 of Set 13 | corinto
# Processing Record 49 of Set 13 | challapata
# Processing Record 50 of Set 13 | damghan
# Processing Record 1 of Set 14 | yenotayevka
# Processing Record 2 of Set 14 | beroroha
# Processing Record 3 of Set 14 | bilina
# Processing Record 4 of Set 14 | kashipur
# Processing Record 5 of Set 14 | puerto suarez
# Processing Record 6 of Set 14 | nylstroom
# City not found. Skipping...
# Processing Record 7 of Set 14 | lere
# Processing Record 8 of Set 14 | concarneau
# Processing Record 9 of Set 14 | nouakchott
# Processing Record 10 of Set 14 | ust-tarka
# Processing Record 11 of Set 14 | chulym
# Processing Record 12 of Set 14 | iskateley
# Processing Record 13 of Set 14 | kedrovyy
# Processing Record 14 of Set 14 | ajdabiya
# Processing Record 15 of Set 14 | hainichen
# Processing Record 16 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 17 of Set 14 | sao paulo de olivenca
# Processing Record 18 of Set 14 | bembereke
# Processing Record 19 of Set 14 | tignere
# Processing Record 20 of Set 14 | santa rosa
# Processing Record 21 of Set 14 | angoche
# Processing Record 22 of Set 14 | gamba
# Processing Record 23 of Set 14 | xanlar
# Processing Record 24 of Set 14 | altay
# Processing Record 25 of Set 14 | stornoway
# Processing Record 26 of Set 14 | ubinskoye
# Processing Record 27 of Set 14 | natal
# Processing Record 28 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 29 of Set 14 | farafangana
# Processing Record 30 of Set 14 | lakota
# Processing Record 31 of Set 14 | bodden town
# Processing Record 32 of Set 14 | pontal do parana
# Processing Record 33 of Set 14 | san ignacio
# Processing Record 34 of Set 14 | maxixe
# Processing Record 35 of Set 14 | mattru
# Processing Record 36 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 37 of Set 14 | maralal
# Processing Record 38 of Set 14 | zhezkazgan
# Processing Record 39 of Set 14 | bakchar
# Processing Record 40 of Set 14 | mora
# Processing Record 41 of Set 14 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 42 of Set 14 | quebec
# Processing Record 43 of Set 14 | vieques
# Processing Record 44 of Set 14 | awassa
# Processing Record 45 of Set 14 | tabuk
# Processing Record 46 of Set 14 | soyo
# Processing Record 47 of Set 14 | luanda
# Processing Record 48 of Set 14 | boa vista
# Processing Record 49 of Set 14 | garsten
# Processing Record 50 of Set 14 | la rioja
# Processing Record 1 of Set 15 | zanjan
# Processing Record 2 of Set 15 | sakti
# Processing Record 3 of Set 15 | kupino
# Processing Record 4 of Set 15 | kouango
# Processing Record 5 of Set 15 | tena
# Processing Record 6 of Set 15 | channarayapatna
# Processing Record 7 of Set 15 | zholymbet
# Processing Record 8 of Set 15 | apastepeque
# Processing Record 9 of Set 15 | ancud
# Processing Record 10 of Set 15 | cabedelo
# Processing Record 11 of Set 15 | bonthe
# Processing Record 12 of Set 15 | severnyy
# Processing Record 13 of Set 15 | rokycany
# Processing Record 14 of Set 15 | san juan del sur
# Processing Record 15 of Set 15 | leamington
# Processing Record 16 of Set 15 | vestmannaeyjar
# Processing Record 17 of Set 15 | abha
# Processing Record 18 of Set 15 | aswan
# Processing Record 19 of Set 15 | owando
# Processing Record 20 of Set 15 | eenhana
# Processing Record 21 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 23 of Set 15 | gaimersheim
# Processing Record 24 of Set 15 | batticaloa
# Processing Record 25 of Set 15 | machali
# Processing Record 26 of Set 15 | kontagora
# Processing Record 27 of Set 15 | sokolo
# Processing Record 28 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 15 | sokone
# Processing Record 30 of Set 15 | krasnozerskoye
# Processing Record 31 of Set 15 | ubala
# Processing Record 32 of Set 15 | oistins
# Processing Record 33 of Set 15 | vestmanna
# Processing Record 34 of Set 15 | uzumlu
# City not found. Skipping...
# Processing Record 35 of Set 15 | camacha
# Processing Record 36 of Set 15 | kalugumalai
# Processing Record 37 of Set 15 | karema
# Processing Record 38 of Set 15 | starobaltachevo
# Processing Record 39 of Set 15 | ginda
# Processing Record 40 of Set 15 | carutapera
# Processing Record 41 of Set 15 | kanniyakumari
# Processing Record 42 of Set 15 | wagar
# Processing Record 43 of Set 15 | aleksandrovskoye
# Processing Record 44 of Set 15 | praia da vitoria
# Processing Record 45 of Set 15 | bogolyubovo
# Processing Record 46 of Set 15 | moussoro
# Processing Record 47 of Set 15 | sandy bay
# Processing Record 48 of Set 15 | lubao
# Processing Record 49 of Set 15 | ravar
# Processing Record 50 of Set 15 | santiago de cao
# Processing Record 1 of Set 16 | tabas
# Processing Record 2 of Set 16 | kindu
# Processing Record 3 of Set 16 | bamako
# Processing Record 4 of Set 16 | manono
# Processing Record 5 of Set 16 | bebra
# Processing Record 6 of Set 16 | sirjan
# Processing Record 7 of Set 16 | puerto cortes
# City not found. Skipping...
# Processing Record 8 of Set 16 | bela
# Processing Record 9 of Set 16 | jumla
# Processing Record 10 of Set 16 | tunceli
# Processing Record 11 of Set 16 | inverness
# Processing Record 12 of Set 16 | numan
# Processing Record 13 of Set 16 | goderich
# Processing Record 14 of Set 16 | am timan
# Processing Record 15 of Set 16 | akkudah
# City not found. Skipping...
# Processing Record 16 of Set 16 | tolbazy
# Processing Record 17 of Set 16 | taloda
# Processing Record 18 of Set 16 | kapuskasing
# Processing Record 19 of Set 16 | ouesso
# Processing Record 20 of Set 16 | gobabis
# Processing Record 21 of Set 16 | jibuti
# Processing Record 22 of Set 16 | litoral del san juan
# City not found. Skipping...
# Processing Record 23 of Set 16 | bonavista
# Processing Record 24 of Set 16 | sahrak
# City not found. Skipping...
# Processing Record 25 of Set 16 | iracoubo
# Processing Record 26 of Set 16 | carbonia
# Processing Record 27 of Set 16 | voi
# Processing Record 28 of Set 16 | okhtyrka
# Processing Record 29 of Set 16 | west bay
# Processing Record 30 of Set 16 | benghazi
# Processing Record 31 of Set 16 | tazmalt
# Processing Record 32 of Set 16 | maloy
# Processing Record 33 of Set 16 | brattvag
# Processing Record 34 of Set 16 | vangaindrano
# Processing Record 35 of Set 16 | salisbury
# Processing Record 36 of Set 16 | haarlemmermeer
# Processing Record 37 of Set 16 | wladyslawowo
# Processing Record 38 of Set 16 | reinosa
# Processing Record 39 of Set 16 | kipini
# Processing Record 40 of Set 16 | buchanan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 725

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           Caravelas -17.7125 -39.2481     67.73        97         100
# 1       Sainte-Maxime  43.3000   6.6333     51.93        96         100
# 2                Chuy -33.6971 -53.4616     58.96        69           1
# 3              Dikson  73.5069  80.5464      9.57        94         100
# 4              Kamthi  21.2333  79.2000     71.94        50          19
# 5  North Myrtle Beach  33.8160 -78.6800     51.06        85           0
# 6             Bubaque  11.2833 -15.8333     81.46        53           0
# 7        Punta Arenas -53.1500 -70.9167     53.11        71         100
# 8            Cidreira -30.1811 -50.2056     70.14        90          65
# 9           Ostrovnoy  68.0531  39.5131     14.97        88          84
#
#    Wind Speed Country                 Date
# 0        2.30      BR  2022-12-16 03:08:18
# 1        8.81      FR  2022-12-16 03:06:15
# 2       10.60      UY  2022-12-16 03:08:18
# 3       20.54      RU  2022-12-16 03:08:19
# 4        4.29      IN  2022-12-16 03:08:19
# 5        3.44      US  2022-12-16 03:08:20
# 6        8.70      GW  2022-12-16 03:08:21
# 7       16.24      CL  2022-12-16 03:03:56
# 8        1.36      BR  2022-12-16 03:08:22
# 9       27.83      RU  2022-12-16 03:08:23

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0         Caravelas      BR -17.7125 -39.2481     67.73        97         100
# 1     Sainte-Maxime      FR  43.3000   6.6333     51.93        96         100
# 2              Chuy      UY -33.6971 -53.4616     58.96        69           1
# 3            Dikson      RU  73.5069  80.5464      9.57        94         100
# 4            Kamthi      IN  21.2333  79.2000     71.94        50          19
# ..              ...     ...      ...      ...       ...       ...         ...
# 720  Haarlemmermeer      NL  52.3000   4.6667     36.03        85           0
# 721    Wladyslawowo      PL  54.7909  18.4009     23.79        88          33
# 722         Reinosa      ES  42.9996  -4.1380     42.46        96         100
# 723          Kipini      KE  -2.5257  40.5262     79.09        84           5
# 724        Buchanan      LR   5.8808 -10.0467     77.40        83          36
#
#      Wind Speed
# 0          2.30
# 1          8.81
# 2         10.60
# 3         20.54
# 4          4.29
# ..          ...
# 720        5.99
# 721        8.90
# 722        2.62
# 723        8.03
# 724        2.62
#
# [725 rows x 8 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
